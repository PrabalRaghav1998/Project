# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline


data=pd.read_csv("fake.csv")

data.head(10)
# Out:
#                                        uuid  ord_in_thread  \
# 0  6a175f46bcd24d39b3e962ad0f29936721db70db              0
# 1  2bdc29d12605ef9cf3f09f9875040a7113be5d5b              0
# 2  c70e149fdd53de5e61c29281100b9de0ed268bc3              0
# 3  7cf7c15731ac2a116dd7f629bd57ea468ed70284              0
# 4  0206b54719c7e241ffe0ad4315b808290dbe6c0f              0
# 5  8f30f5ea14c9d5914a9fe4f55ab2581772af4c31              0
# 6  d3cc0fe38f41a59f7c48f8c3528ca5f74193148f              0
# 7  b4bbf8b5c19e8864f5257832a58b81ef4ed2d4e4              0
# 8  a19aabaa5a61eb8bc22fadaaa003e5fbba5c4bf6              0
# 9  f54d8e13010d0a79893995ee65360ad4b38b5a35              0
#
#                  author                      published  \
# 0     Barracuda Brigade  2016-10-26T21:41:00.000+03:00
# 1  reasoning with facts  2016-10-29T08:47:11.259+03:00
# 2     Barracuda Brigade  2016-10-31T01:41:49.479+02:00
# 3                Fed Up  2016-11-01T05:22:00.000+02:00
# ...

# %%
data.shape
# Out:
# (12999, 20)

# %%
s=sns.countplot(x="type",data=data)

# %%
data.dtypes
# Out:
# uuid                   object
# ord_in_thread           int64
# author                 object
# published              object
# title                  object
# text                   object
# language               object
# crawled                object
# site_url               object
# country                object
# domain_rank           float64
# thread_title           object
# spam_score            float64
# main_img_url           object
# replies_count           int64
# participants_count      int64
# likes                   int64
# comments                int64
# shares                  int64
# type                   object
# dtype: object

# %%
data.columns
# Out:
# Index(['uuid', 'ord_in_thread', 'author', 'published', 'title', 'text',
#        'language', 'crawled', 'site_url', 'country', 'domain_rank',
#        'thread_title', 'spam_score', 'main_img_url', 'replies_count',
#        'participants_count', 'likes', 'comments', 'shares', 'type'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# uuid                     0
# ord_in_thread            0
# author                2424
# published                0
# title                  680
# text                    46
# language                 0
# crawled                  0
# site_url                 0
# country                176
# domain_rank           4223
# thread_title            12
# spam_score               0
# main_img_url          3643
# replies_count            0
# participants_count       0
# likes                    0
# comments                 0
# shares                   0
# type                     0
# dtype: int64

# %%
#Remove the rows which contain author as null
data1=data[pd.notnull(data["author"])]

# %%
#Remove the rows which contain title as null
data2=data1[pd.notnull(data1["title"])]

# %%
data2.shape
# Out:
# (9895, 20)

# %%
data2.type.value_counts(normalize=True)*100
# Out:
# bs            90.692269
# bias           2.930773
# conspiracy     2.718545
# hate           2.475998
# junksci        0.980293
# fake           0.141486
# state          0.060637
# Name: type, dtype: float64

# %%
#Before removing null values
data.type.value_counts()
# Out:
# bs            11492
# bias            443
# conspiracy      430
# hate            246
# satire          146
# state           121
# junksci         102
# fake             19
# Name: type, dtype: int64

# %%
#After removing null values
data2.type.value_counts()
# Out:
# bs            8974
# bias           290
# conspiracy     269
# hate           245
# junksci         97
# fake            14
# state            6
# Name: type, dtype: int64

# %%
data2.describe(include="all")
# Out:
#                                             uuid  ord_in_thread author  \
# count                                       9895         9895.0   9895
# unique                                      9895            NaN   1836
# top     8634017d47b1db21b51842434f62988f9d8d7d73            NaN  admin
# freq                                           1            NaN    247
# mean                                         NaN            0.0    NaN
# std                                          NaN            0.0    NaN
# min                                          NaN            0.0    NaN
# 25%                                          NaN            0.0    NaN
# 50%                                          NaN            0.0    NaN
# 75%                                          NaN            0.0    NaN
# max                                          NaN            0.0    NaN
#
#                             published  \
# count                            9895
# ...

# %%
s=sns.countplot(x="type",data=data2)
